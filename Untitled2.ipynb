# %%
import tensorflow as tf

text_file = tf.keras.utils.get_file(
    fname="fra-eng.zip",
    origin="https://storage.googleapis.com/download.tensorflow.org/data/fra-eng.zip",
    extract=False
)
print(text_file)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/fra-eng.zip
# 3423204/3423204 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /root/.keras/datasets/fra-eng.zip

# %%
import zipfile, os

with zipfile.ZipFile(text_file, "r") as z:
    z.extractall(os.path.dirname(text_file))

# %%
from pathlib import Path
import random

text_file = Path(text_file).parent / "fra.txt"

with open(text_file, encoding="utf-8") as f:
    text_pairs = f.readlines()

for _ in range(5):
    print(random.choice(text_pairs))
# Out:
# Don't you think we deserve some answers?	Ne pensez-vous pas que nous méritions quelques réponses ?
#
# Have you ever eaten at that restaurant?	Avez-vous jamais mangé dans ce restaurant ?
#
# That hit the spot.	C'était parfait.
#
# I slammed the door shut.	J'ai claqué la porte.
#
# She forced him to sit down.	Elle le contraignit à s'asseoir.

# %%
import unicodedata, re

def normalize(line):
  line = unicodedata.normalize("NFKC",line.strip().lower())
  line = re.sub(r"^([^\w])(?!\s)",r"\1",line)
  line = re.sub(r"(\s[^\w])(?!\s)",r"\1",line)
  line = re.sub(r"(?!\s)([^\w])$",r"\1",line)
  line = re.sub(r"(?!\s)([^\w]\s)",r"\1",line)
  eng, fre = line.split("\t")
  fre = '[start]' + fre + '[end]'
  return eng, fre

# %%
with open(text_file) as fp :
  test_pairs = [normalize(line) for line in fp]

# %%
for _ in range(5):
  print(random.choice(test_pairs))
# Out:
# ('where did you put my keys?', '[start]où avez-vous mis mes clés ?[end]')
# ("tom didn't tell mary why he was late.", "[start]tom n'a pas dit à mary pourquoi il était en retard.[end]")
# ('it was kind of fun.', "[start]c'était en quelque sorte amusant.[end]")
# ('have a good weekend!', '[start]passe un bon week-end ![end]')
# ("we didn't need to do that.", "[start]nous n'avons pas eu besoin de faire ça.[end]")

# %%
eng_tokens, fre_tokens = set(), set()
eng_maxlen, fre_maxlen = 0, 0
for eng, fre in test_pairs:
  eng_token, fre_token = eng.split(), fre.split()
  eng_maxlen = max(eng_maxlen, len(eng_token))
  fre_maxlen = max(fre_maxlen, len(fre_token))
  eng_tokens.update(eng_token)
  fre_tokens.update(fre_token)

print(f"Total token in english is : {len(eng_tokens)}")
print(f"Total token in french is : {len(fre_tokens)}")
print(f"Maximum length of line is : {eng_maxlen}")
print(f"Maximum length of line is : {fre_maxlen}")
# Out:
# Total token in english is : 25365
# Total token in french is : 44581
# Maximum length of line is : 47
# Maximum length of line is : 54

# %%
import pickle
with open("test_pairs.pickle","wb") as fp:
  pickle.dump(test_pairs,fp)

# %%
# embedding layer
# positional encoding
# attention model

# %%
from tensorflow.keras.layers import TextVectorization
import pickle

with open("test_pairs.pickle",'rb') as fp:
  text_pairs = pickle.load(fp)

# %%
random.shuffle(text_pairs)

# %%
n_val = int(.15*len(text_pairs))
n_train = len(text_pairs) - 2*n_val
train_pair = text_pairs[:n_train]
test_pair = text_pairs[n_train: n_train + n_val]

# %%
vacab_en = 10000
vocab_fr = 20000
seq_len = 25

# %%
eng_vec = TextVectorization(
    max_tokens=vacab_en,
    standardize = None,
    split = 'whitespace',
    output_mode = 'int',
    output_sequence_length = seq_len
)

# %%
fr_vec = TextVectorization(
    max_tokens=vocab_fr,
    standardize = None,
    split = 'whitespace',
    output_mode = 'int',
    output_sequence_length = seq_len
)

# %%
train_eng = [pair[0] for pair in train_pair]
train_fr = [pair[1] for pair in train_pair]

# %%
eng_vec.adapt(train_eng)
fr_vec.adapt(train_fr)

# %%
with open('vectorization.pickle', 'wb') as fp:
  data = {'train': train_pair,
          'test': test_pair,
          'eng_vec': eng_vec.get_config(),
          'fr_vec': fr_vec.get_config(),
          'eng_weights':eng_vec.get_weights(),
          'fr_weights':fr_vec.get_weights()
          }
  pickle.dump(data, fp)

# %%
with open('vectorization.pickle', 'rb') as fp:
  data = pickle.load(fp)

# %%
train_pair = data['train']
test_pair = data['test']

eng_vec = TextVectorization.from_config(data['eng_vec'])
fr_vec = TextVectorization.from_config(data['fr_vec'])

eng_vec.set_weights(data['eng_weights'])
fr_vec.set_weights(data['fr_weights'])

# %%
def format_datasets(eng, fr):
  eng = eng_vec(eng)
  fr = fr_vec(fr)
  source = {
            'encoder_inputs': eng,
            'decoder_inputs': fr[:,:-1]
            }
  target = fr[:,1:]
  return (source, target)

def make_datasets(pairs, batchsize = 64):
  eng_text, fr_text = zip(*pairs)
  dataset = tf.data.Dataset.from_tensor_slices((eng_text), (fr_text))

  return dataset.shuffle(2048).batch(batchsize).map(format_datasets).prefetch(16).cache()

# %%
test_pair

# %%
train_ds = make_datasets(train_pair)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1266059038.py in <cell line: 0>()
# ----> 1 train_ds = make_datasets(train_pair)
#
# /tmp/ipython-input-1311430049.py in make_datasets(pairs, batchsize)
#      11 def make_datasets(pairs, batchsize = 64):
#      12   eng_text, fr_text = zip(*pairs)
# ---> 13   dataset = tf.data.Dataset.from_tensor_slices((eng_text), (fr_text))
#      14
#      15   return dataset.shuffle(2048).batch(batchsize).map(format_datasets).prefetch(16).cache()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors, name)
#     825     # pylint: disable=g-import-not-at-top,protected-access
#     826     from tensorflow.python.data.ops import from_tensor_slices_op
# --> 827     return from_tensor_slices_op._from_tensor_slices(tensors, name)
#     828     # pylint: enable=g-import-not-at-top,protected-access
#     829
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/from_tensor_slices_op.py in _from_tensor_slices(tensors, name)
#      23
#      24 def _from_tensor_slices(tensors, name=None):
# ---> 25   return _TensorSliceDataset(tensors, name=name)
#      26
#      27
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/from_tensor_slices_op.py in __init__(self, element, is_files, name)
#      33     element = structure.normalize_element(element)
#      34     batched_spec = structure.type_spec_from_value(element)
# ---> 35     self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#      36     if not self._tensors:
#      37       raise ValueError("Invalid `element`. `element` should not be empty.")
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/util/structure.py in to_batched_tensor_list(element_spec, element)
#     384   # pylint: disable=protected-access
#     385   # pylint: disable=g-long-lambda
# --> 386   return _to_tensor_list_helper(
#     387       lambda state, spec, component: state + spec._to_batched_tensor_list(
#     388           component), element_spec, element)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/util/structure.py in _to_tensor_list_helper(encode_fn, element_spec, element)
#     359     return encode_fn(state, spec, component)
#     360
# --> 361   return functools.reduce(
#     362       reduce_fn, zip(nest.flatten(element_spec), nest.flatten(element)), [])
#     363
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/util/structure.py in reduce_fn(state, value)
#     342   nest.assert_same_structure(element_spec, element)
#     343
# --> 344   def reduce_fn(state, value):
#     345     spec, component = value
#     346     if isinstance(spec, internal.TensorSpec):
#
# KeyboardInterrupt:
